# %% [markdown]
# # 🏠 Ames Housing Price Prediction Project
# Bu projede, Ames Housing veri seti ile ev fiyatlarını tahmin edeceğiz.

# %% [markdown]
# ## 1. Veri Setinin Yüklenmesi

# %%
import pandas as pd
import numpy as np

# Veri setini yükle
df = pd.read_csv('../data/your_dataset.csv')
df.head()

# %% [markdown]
# ## 2. Veri Setine Genel Bakış

# %%
# Şekil, tipler, boş veriler
print(df.shape)
df.info()
df.describe()

# %% [markdown]
# ## 3. Eksik Değerlerin İncelenmesi ve Temizlenmesi

# %%
# Eksik verileri görselleştir veya analiz et

# %% [markdown]
# ## 4. Görselleştirme ve Özellik Analizi

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Örnek: df['SalePrice'].hist()

# %% [markdown]
# ## 5. Feature Engineering

# %%
# Gerekirse kategorik değişkenleri encode et, yeni özellikler oluştur

# %% [markdown]
# ## 6. Veriyi Train/Test Olarak Ayırma

# %%
from sklearn.model_selection import train_test_split

# Örnek: X = df.drop('SalePrice', axis=1); y = df['SalePrice']

# %% [markdown]
# ## 7. Model Eğitimi (Linear Regression)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)

# %% [markdown]
# ## 8. Model Değerlendirme

# %%
from sklearn.metrics import mean_squared_error, r2_score

y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f"MSE: {mse:.2f}, R2: {r2:.2f}")

# %% [markdown]
# ## 9. Sonuçların Görselleştirilmesi

# %%
# Gerçek vs Tahmin karşılaştırması vs.

# %% [markdown]
# ## 10. Kapanış ve Öneriler

# %% [markdown]
# Bu bölümde elde edilen sonuçları yorumlayabilir, modelin geliştirilmesi için önerilerde bulunabilirsin.
